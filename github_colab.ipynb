# %% [markdown]
# <a href="https://colab.research.google.com/github/sayeon-co-lee/cs1-python-emerald-belida/blob/main/github_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Sayeon.")
# Out:
# Hello Sayeon.
